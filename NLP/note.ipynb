# %% [markdown]
# # Verify via Code Execution

# %%
import os
if 'COLAB_RELEASE_TAG' in os.environ:
    print("Running on Google Colab!")
else:
    print("Running locally.")
# Out:
# Running on Google Colab!

# %% [markdown]
# # stemming

# %%
print("Hello, World!")
